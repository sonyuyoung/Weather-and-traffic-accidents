# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc


accidentInfoList = pd.read_csv("./부산광역시전체교통사고.csv")
accidentInfoList
# Out:
#                사고번호               사고일시   요일              시군구  사고내용  사망자수  \
# 0      2.022010e+15    2022년 1월 1일 00시  토요일   부산광역시 부산진구 부전동  중상사고     0
# 1      2.022010e+15    2022년 1월 1일 00시  토요일   부산광역시 강서구 대저1동  중상사고     0
# 2      2.022010e+15    2022년 1월 1일 05시  토요일    부산광역시 동래구 명장동  경상사고     0
# 3      2.022010e+15    2022년 1월 1일 06시  토요일    부산광역시 강서구 대항동  경상사고     0
# 4      2.022010e+15    2022년 1월 1일 14시  토요일     부산광역시 남구 용호동  경상사고     0
# ...             ...                ...  ...              ...   ...   ...
# 10877  2.022123e+15  2022년 12월 31일 19시  토요일    부산광역시 사하구 감천동  경상사고     0
# 10878  2.022123e+15  2022년 12월 31일 20시  토요일     부산광역시 북구 구포동  경상사고     0
# 10879  2.022123e+15  2022년 12월 31일 20시  토요일  부산광역시 영도구 봉래동5가  중상사고     0
# 10880  2.022123e+15  2022년 12월 31일 22시  토요일    부산광역시 사상구 삼락동  중상사고     0
# 10881  2.022123e+15  2022년 12월 31일 23시  토요일  부산광역시 서구 동대신동1가  중상사고     0
#
#        중상자수  경상자수  부상신고자수        사고유형  ... 기상상태         도로형태 가해운전자 차종  \
# ...
